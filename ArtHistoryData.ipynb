# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
artists_file = "Resources/artists.csv"
artists_df = pd.read_csv(artists_file)
artists_df.head()
# Out:
#    Artist ID             Name Nationality Gender  Birth Year  Death Year
# 0          1   Robert Arneson    American   Male      1930.0      1992.0
# 1          2   Doroteo Arnaiz     Spanish   Male      1936.0         NaN
# 2          3      Bill Arnold    American   Male      1941.0         NaN
# 3          4  Charles Arnoldi    American   Male      1946.0         NaN
# 4          5      Per Arnoldi      Danish   Male      1941.0         NaN

# %%
conn = "postgres:Brit@localhost:5432/ArtHistory"
engine = create_engine(f'postgresql://{conn}')

# %%
artworks_file = "Resources/artworks.csv"
artworks_df = pd.read_csv(artworks_file)
artworks_df.head()
# Out:
#    Artwork ID                                              Title Artist ID  \
# 0           2  Ferdinandsbrücke Project, Vienna, Austria, Ele...      6210
# 1           3  City of Music, National Superior Conservatory ...      7470
# 2           4  Villa near Vienna Project, Outside Vienna, Aus...      7605
# 3           5  The Manhattan Transcripts Project, New York, N...      7056
# 4           6  Villa, project, outside Vienna, Austria, Exter...      7605
#
#                        Name  Date  \
# 0               Otto Wagner  1896
# 1  Christian de Portzamparc  1987
# 2                Emil Hoppe  1903
# 3           Bernard Tschumi  1980
# 4                Emil Hoppe  1903
#
#                                               Medium  \
# 0      Ink and cut-and-pasted painted pages on paper
# 1                  Paint and colored pencil on print
# 2  Graphite, pen, color pencil, ink, and gouache ...
# 3  Photographic reproduction with colored synthet...
# ...

# %%
artists_df_clean = artists_df.loc[artists_df['Birth Year'].isna() == False]
artists_df_clean
# Out:
#        Artist ID             Name Nationality  Gender  Birth Year  Death Year
# 0              1   Robert Arneson    American    Male      1930.0      1992.0
# 1              2   Doroteo Arnaiz     Spanish    Male      1936.0         NaN
# 2              3      Bill Arnold    American    Male      1941.0         NaN
# 3              4  Charles Arnoldi    American    Male      1946.0         NaN
# 4              5      Per Arnoldi      Danish    Male      1941.0         NaN
# ...          ...              ...         ...     ...         ...         ...
# 15082      67379          N. Dash    American  Female      1980.0         NaN
# 15084      67437  Sebastian Black    American    Male      1985.0         NaN
# 15085      67451          Xiao Yu     Chinese    Male      1965.0         NaN
# 15086      67452      Liu Jianhua     Chinese    Male      1962.0         NaN
# 15087      67453         Leng Lin     Chinese    Male      1965.0         NaN
#
# [11237 rows x 6 columns]

# %%
artists_df_clean = artists_df_clean.drop_duplicates(['Artist ID'])
artists_df_clean
# Out:
#        Artist ID             Name Nationality  Gender  Birth Year  Death Year
# 0              1   Robert Arneson    American    Male      1930.0      1992.0
# 1              2   Doroteo Arnaiz     Spanish    Male      1936.0         NaN
# 2              3      Bill Arnold    American    Male      1941.0         NaN
# 3              4  Charles Arnoldi    American    Male      1946.0         NaN
# 4              5      Per Arnoldi      Danish    Male      1941.0         NaN
# ...          ...              ...         ...     ...         ...         ...
# 15082      67379          N. Dash    American  Female      1980.0         NaN
# 15084      67437  Sebastian Black    American    Male      1985.0         NaN
# 15085      67451          Xiao Yu     Chinese    Male      1965.0         NaN
# 15086      67452      Liu Jianhua     Chinese    Male      1962.0         NaN
# 15087      67453         Leng Lin     Chinese    Male      1965.0         NaN
#
# [11237 rows x 6 columns]

# %%
artists_df_clean_new = artists_df_clean[["Artist ID", "Name", "Nationality", "Gender", "Birth Year"]].copy()
artists_df_clean_new = artists_df_clean_new

# %%
artists_df_final = artists_df_clean_new.rename(columns={"Artist ID":"artist_id", "Name":"name", "Nationality":"nationality", "Gender":"gender", "Birth Year": "birth_year"})

# %%
artists_df_final
# Out:
#        artist_id             name nationality  gender  birth_year
# 0              1   Robert Arneson    American    Male      1930.0
# 1              2   Doroteo Arnaiz     Spanish    Male      1936.0
# 2              3      Bill Arnold    American    Male      1941.0
# 3              4  Charles Arnoldi    American    Male      1946.0
# 4              5      Per Arnoldi      Danish    Male      1941.0
# ...          ...              ...         ...     ...         ...
# 15082      67379          N. Dash    American  Female      1980.0
# 15084      67437  Sebastian Black    American    Male      1985.0
# 15085      67451          Xiao Yu     Chinese    Male      1965.0
# 15086      67452      Liu Jianhua     Chinese    Male      1962.0
# 15087      67453         Leng Lin     Chinese    Male      1965.0
#
# [11237 rows x 5 columns]

# %%
artists_df_final.set_index("artist_id", inplace=True)
artists_df_final
# Out:
#                       name nationality  gender  birth_year
# artist_id
# 1           Robert Arneson    American    Male      1930.0
# 2           Doroteo Arnaiz     Spanish    Male      1936.0
# 3              Bill Arnold    American    Male      1941.0
# 4          Charles Arnoldi    American    Male      1946.0
# 5              Per Arnoldi      Danish    Male      1941.0
# ...                    ...         ...     ...         ...
# 67379              N. Dash    American  Female      1980.0
# 67437      Sebastian Black    American    Male      1985.0
# 67451              Xiao Yu     Chinese    Male      1965.0
# 67452          Liu Jianhua     Chinese    Male      1962.0
# 67453             Leng Lin     Chinese    Male      1965.0
#
# [11237 rows x 4 columns]

# %%
artists_df_final.dtypes
# Out:
# name            object
# nationality     object
# gender          object
# birth_year     float64
# dtype: object

# %%
artworks_df['Department']
# Out:
# 0              Architecture & Design
# 1              Architecture & Design
# 2              Architecture & Design
# 3              Architecture & Design
# 4              Architecture & Design
#                      ...
# 130257             Fluxus Collection
# 130258             Fluxus Collection
# 130259             Fluxus Collection
# 130260             Fluxus Collection
# 130261    Prints & Illustrated Books
# Name: Department, Length: 130262, dtype: object

# %%
artworks_df_clean = artworks_df[['Artwork ID', 'Title', 'Artist ID', 'Date', 'Department', 'Classification', 'Medium']].copy()
artworks_df_clean
# Out:
#         Artwork ID                                              Title  \
# 0                2  Ferdinandsbrücke Project, Vienna, Austria, Ele...
# 1                3  City of Music, National Superior Conservatory ...
# 2                4  Villa near Vienna Project, Outside Vienna, Aus...
# 3                5  The Manhattan Transcripts Project, New York, N...
# 4                6  Villa, project, outside Vienna, Austria, Exter...
# ...            ...                                                ...
# 130257      217983                                        Seul/NY/MAX
# 130258      217984   Fluxus-Manifestatie in en Rond Kunsthandel Monet
# 130259      217985                             Fluxphone Compositions
# 130260      217986                                       Unidentified
# 130261      218011                           Portrait of Takako Saito
#
#        Artist ID  Date                  Department Classification  \
# ...

# %%
artworks_df_clean = artworks_df_clean.drop_duplicates(['Artwork ID'])
artworks_df_clean
# Out:
#         Artwork ID                                              Title  \
# 0                2  Ferdinandsbrücke Project, Vienna, Austria, Ele...
# 1                3  City of Music, National Superior Conservatory ...
# 2                4  Villa near Vienna Project, Outside Vienna, Aus...
# 3                5  The Manhattan Transcripts Project, New York, N...
# 4                6  Villa, project, outside Vienna, Austria, Exter...
# ...            ...                                                ...
# 130257      217983                                        Seul/NY/MAX
# 130258      217984   Fluxus-Manifestatie in en Rond Kunsthandel Monet
# 130259      217985                             Fluxphone Compositions
# 130260      217986                                       Unidentified
# 130261      218011                           Portrait of Takako Saito
#
#        Artist ID  Date                  Department Classification  \
# ...

# %%
# artworks_df_clean.set_index(['Artwork ID'], inplace=True)
# artworks_df_clean

# %%
artworks_df_final = artworks_df_clean.dropna()
artworks_df_final.head()
# Out:
#    Artwork ID                                              Title Artist ID  \
# 0           2  Ferdinandsbrücke Project, Vienna, Austria, Ele...      6210
# 1           3  City of Music, National Superior Conservatory ...      7470
# 2           4  Villa near Vienna Project, Outside Vienna, Aus...      7605
# 3           5  The Manhattan Transcripts Project, New York, N...      7056
# 4           6  Villa, project, outside Vienna, Austria, Exter...      7605
#
#    Date             Department Classification  \
# 0  1896  Architecture & Design   Architecture
# 1  1987  Architecture & Design   Architecture
# 2  1903  Architecture & Design   Architecture
# 3  1980  Architecture & Design   Architecture
# 4  1903  Architecture & Design   Architecture
#
#                                               Medium
# 0      Ink and cut-and-pasted painted pages on paper
# 1                  Paint and colored pencil on print
# 2  Graphite, pen, color pencil, ink, and gouache ...
# ...

# %%
artworks_df_final.dtypes
# Out:
# Artwork ID         int64
# Title             object
# Artist ID         object
# Date              object
# Department        object
# Classification    object
# Medium            object
# dtype: object

# %%
artists_df_final.dtypes
# Out:
# name            object
# nationality     object
# gender          object
# birth_year     float64
# dtype: object

# %%
test = artworks_df_final.drop

# %%
artworks_df_final = artworks_df_final.loc[artworks_df_final['Artist ID'].str.contains(" ")==False]

# %%
artworks_df_final['Artist ID']
# Out:
# 0          6210
# 1          7470
# 2          7605
# 3          7056
# 4          7605
#           ...
# 130219     1634
# 130220     1634
# 130221     1634
# 130244     2637
# 130259    67695
# Name: Artist ID, Length: 110069, dtype: object

# %%
artworks_df_final['Artist ID'] = artworks_df_final['Artist ID'].astype(int)
# Out:
# C:\Users\hills\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
artworks_df_final.dtypes
# Out:
# Artwork ID         int64
# Title             object
# Artist ID          int32
# Date              object
# Department        object
# Classification    object
# Medium            object
# dtype: object

# %%
art_Final = artworks_df_final.rename(columns ={"Artwork ID": "artwork_id", "Title":"title", "Artist ID": "artist_id", "Date": "date", "Department": "department", "Classification": "classification", "Medium": "medium"})

# %%
art_Final
# Out:
#         artwork_id                                              title  \
# 0                2  Ferdinandsbrücke Project, Vienna, Austria, Ele...
# 1                3  City of Music, National Superior Conservatory ...
# 2                4  Villa near Vienna Project, Outside Vienna, Aus...
# 3                5  The Manhattan Transcripts Project, New York, N...
# 4                6  Villa, project, outside Vienna, Austria, Exter...
# ...            ...                                                ...
# 130219      217893                        Rotoreliefs (Optical Disks)
# 130220      217894                        Rotoreliefs (Optical Disks)
# 130221      217895                        Rotoreliefs (Optical Disks)
# 130244      217970                 Vocal Composition 1959, and others
# 130259      217985                             Fluxphone Compositions
#
#         artist_id                  date                  department  \
# ...

# %%
art_Final.dropna(subset=['artwork_id'])
# Out:
#         artwork_id                                              title  \
# 0                2  Ferdinandsbrücke Project, Vienna, Austria, Ele...
# 1                3  City of Music, National Superior Conservatory ...
# 2                4  Villa near Vienna Project, Outside Vienna, Aus...
# 3                5  The Manhattan Transcripts Project, New York, N...
# 4                6  Villa, project, outside Vienna, Austria, Exter...
# ...            ...                                                ...
# 130219      217893                        Rotoreliefs (Optical Disks)
# 130220      217894                        Rotoreliefs (Optical Disks)
# 130221      217895                        Rotoreliefs (Optical Disks)
# 130244      217970                 Vocal Composition 1959, and others
# 130259      217985                             Fluxphone Compositions
#
#         artist_id                  date                  department  \
# ...

# %%
art_Final.index.names = ['artwork_id']

# %%
art_Final
# Out:
#             artwork_id                                              title  \
# artwork_id
# 0                    2  Ferdinandsbrücke Project, Vienna, Austria, Ele...
# 1                    3  City of Music, National Superior Conservatory ...
# 2                    4  Villa near Vienna Project, Outside Vienna, Aus...
# 3                    5  The Manhattan Transcripts Project, New York, N...
# 4                    6  Villa, project, outside Vienna, Austria, Exter...
# ...                ...                                                ...
# 130219          217893                        Rotoreliefs (Optical Disks)
# 130220          217894                        Rotoreliefs (Optical Disks)
# 130221          217895                        Rotoreliefs (Optical Disks)
# 130244          217970                 Vocal Composition 1959, and others
# 130259          217985                             Fluxphone Compositions
#
# ...

# %%
art = art_Final.to_sql(name='artworks', con = conn, if_exists = 'append', index = False)
# Out:
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# <ipython-input-29-098d21e4cc8b> in <module>
# ----> 1 art = art_Final.to_sql(name='artworks', con = conn, if_exists = 'append', index = False)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     501         raise ValueError(f"'{if_exists}' is not valid for if_exists")
#     502
# --> 503     pandas_sql = pandasSQL_builder(con, schema=schema)
#     504
#     505     if isinstance(frame, Series):
#
# ...

# %%
art_Final.index.dropna()
